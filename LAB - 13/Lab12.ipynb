# %% [markdown]
# # Lab 13

# %% [markdown]
# ## Section 1: PyTorch

# %% [markdown]
# ## Import Torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in e:\anaconda\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in e:\anaconda\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\anaconda\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in e:\anaconda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in e:\anaconda\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in e:\anaconda\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')


sample_input = torch.randn(1, 10).to(device)
type(sample_input)
# Out:
# Using device: cpu
# torch.Tensor

# %%
sample_input
# Out:
# tensor([[-1.3204,  0.4781,  1.0135,  0.4073,  0.0301, -0.7481,  0.9513,  0.7125,
#          -0.1015,  0.1821]])

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:04<00:00, 2.12MB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 99.7kB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:01<00:00, 901kB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<?, ?B/s]

# %%
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
img, label = training_data[0]

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
img
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0706, 0.0706, 0.0706,
#           0.4941, 0.5333, 0.6863, 0.1020, 0.6510, 1.0000, 0.9686, 0.4980,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1176, 0.1412, 0.3686, 0.6039, 0.6667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.8824, 0.6745, 0.9922, 0.9490, 0.7647, 0.2510,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922,
#           0.9333, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9843, 0.3647, 0.3216, 0.3216, 0.2196, 0.1529, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765, 0.7137,
#           0.9686, 0.9451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3137, 0.6118, 0.4196, 0.9922, 0.9922, 0.8039, 0.0431, 0.0000,
#           0.1686, 0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0549, 0.0039, 0.6039, 0.9922, 0.3529, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.7451, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0431, 0.7451, 0.9922, 0.2745, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1373, 0.9451, 0.8824, 0.6275,
#           0.4235, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3176, 0.9412, 0.9922,
#           0.9922, 0.4667, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.7294,
#           0.9922, 0.9922, 0.5882, 0.1059, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0627,
#           0.3647, 0.9882, 0.9922, 0.7333, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.9765, 0.9922, 0.9765, 0.2510, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1804, 0.5098,
#           0.7176, 0.9922, 0.9922, 0.8118, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1529, 0.5804, 0.8980, 0.9922,
#           0.9922, 0.9922, 0.9804, 0.7137, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0941, 0.4471, 0.8667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.7882, 0.3059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0902, 0.2588, 0.8353, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765,
#           0.3176, 0.0078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.6706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.7647, 0.3137, 0.0353,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.2157, 0.6745, 0.8863, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9569, 0.5216, 0.0431, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.5333, 0.9922, 0.9922, 0.9922,
#           0.8314, 0.5294, 0.5176, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(), cmap="gray")
plt.title(f"This is a number {label}")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
import torch.nn as nn

class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            nn.Linear(784, 450), 
            nn.Linear(450, 300), 
            nn.Linear(300, 210), 
            nn.Linear(210, 128), 
            nn.ReLU(),# Activation 
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=450, bias=True)
#     (1): Linear(in_features=450, out_features=300, bias=True)
#     (2): Linear(in_features=300, out_features=210, bias=True)
#     (3): Linear(in_features=210, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

print(len(train_loader),"--",len(test_loader))
# Out:
# 938 -- 157

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train():
    model.train()
    
    # Epoch Loop - Train for multiple epochs
    num_epochs = 80
    
    for epoch in range(num_epochs):
        print(f"\n--- Epoch {epoch + 1}/{num_epochs} ---")
        
        for batch_No, (data, target) in enumerate(train_loader):
            
            output = model(data)
            
            loss = loss_fn(output, target)
            
            # Backpropagation
            optimizer.zero_grad()  # Clear old calculations
            loss.backward()        # Calculate gradients
            optimizer.step()       # Update weights
            
            if batch_No % 100 == 0:
                print(f"Batch {batch_No}: Loss = {loss.item():.4f}")
        
        print(f"Epoch {epoch + 1} completed!")

# Run training

# %%
train()
# Out:
# --- Epoch 1/80 ---
# Batch 0: Loss = 2.3082
# Batch 100: Loss = 0.3449
# Batch 200: Loss = 0.4561
# Batch 300: Loss = 0.2875
# Batch 400: Loss = 0.4520
# Batch 500: Loss = 0.2250
# Batch 600: Loss = 0.1738
# Batch 700: Loss = 0.1278
# Batch 800: Loss = 0.4282
# Batch 900: Loss = 0.4062
# Epoch 1 completed!
#
# --- Epoch 2/80 ---
# Batch 0: Loss = 0.1823
# Batch 100: Loss = 0.3547
# Batch 200: Loss = 0.2726
# Batch 300: Loss = 0.1840
# Batch 400: Loss = 0.2909
# Batch 500: Loss = 0.2846
# Batch 600: Loss = 0.2497
# Batch 700: Loss = 0.1560
# Batch 800: Loss = 0.1393
# Batch 900: Loss = 0.2207
# Epoch 2 completed!
#
# --- Epoch 3/80 ---
# Batch 0: Loss = 0.1480
# Batch 100: Loss = 0.3113
# Batch 200: Loss = 0.1706
# Batch 300: Loss = 0.2172
# Batch 400: Loss = 0.2422
# Batch 500: Loss = 0.0890
# Batch 600: Loss = 0.2141
# Batch 700: Loss = 0.2827
# Batch 800: Loss = 0.0715
# Batch 900: Loss = 0.2564
# Epoch 3 completed!
#
# --- Epoch 4/80 ---
# Batch 0: Loss = 0.1123
# Batch 100: Loss = 0.1781
# Batch 200: Loss = 0.0648
# Batch 300: Loss = 0.0706
# Batch 400: Loss = 0.3109
# Batch 500: Loss = 0.1430
# Batch 600: Loss = 0.1892
# Batch 700: Loss = 0.0544
# Batch 800: Loss = 0.1359
# Batch 900: Loss = 0.0571
# Epoch 4 completed!
#
# --- Epoch 5/80 ---
# Batch 0: Loss = 0.0235
# Batch 100: Loss = 0.1165
# Batch 200: Loss = 0.1263
# Batch 300: Loss = 0.1949
# Batch 400: Loss = 0.1740
# Batch 500: Loss = 0.2105
# Batch 600: Loss = 0.2552
# Batch 700: Loss = 0.1244
# Batch 800: Loss = 0.2989
# Batch 900: Loss = 0.2791
# Epoch 5 completed!
#
# --- Epoch 6/80 ---
# Batch 0: Loss = 0.1126
# Batch 100: Loss = 0.0478
# Batch 200: Loss = 0.1310
# Batch 300: Loss = 0.0624
# Batch 400: Loss = 0.2664
# Batch 500: Loss = 0.2558
# Batch 600: Loss = 0.1200
# Batch 700: Loss = 0.0451
# Batch 800: Loss = 0.1038
# Batch 900: Loss = 0.2020
# Epoch 6 completed!
#
# --- Epoch 7/80 ---
# Batch 0: Loss = 0.1125
# Batch 100: Loss = 0.0743
# Batch 200: Loss = 0.0275
# Batch 300: Loss = 0.0524
# Batch 400: Loss = 0.0301
# Batch 500: Loss = 0.2984
# Batch 600: Loss = 0.2015
# Batch 700: Loss = 0.1988
# Batch 800: Loss = 0.1326
# Batch 900: Loss = 0.0650
# Epoch 7 completed!
#
# --- Epoch 8/80 ---
# Batch 0: Loss = 0.1008
# Batch 100: Loss = 0.1187
# Batch 200: Loss = 0.0403
# Batch 300: Loss = 0.0677
# Batch 400: Loss = 0.0941
# Batch 500: Loss = 0.2362
# Batch 600: Loss = 0.1685
# Batch 700: Loss = 0.1524
# Batch 800: Loss = 0.0540
# Batch 900: Loss = 0.0570
# Epoch 8 completed!
#
# --- Epoch 9/80 ---
# Batch 0: Loss = 0.1389
# Batch 100: Loss = 0.0918
# Batch 200: Loss = 0.1927
# Batch 300: Loss = 0.0139
# Batch 400: Loss = 0.0562
# Batch 500: Loss = 0.1365
# Batch 600: Loss = 0.1123
# Batch 700: Loss = 0.0518
# Batch 800: Loss = 0.0207
# Batch 900: Loss = 0.1008
# Epoch 9 completed!
#
# --- Epoch 10/80 ---
# Batch 0: Loss = 0.0767
# Batch 100: Loss = 0.1621
# Batch 200: Loss = 0.0903
# Batch 300: Loss = 0.1399
# Batch 400: Loss = 0.1249
# Batch 500: Loss = 0.1701
# Batch 600: Loss = 0.0957
# Batch 700: Loss = 0.1018
# Batch 800: Loss = 0.1860
# Batch 900: Loss = 0.0944
# Epoch 10 completed!
#
# --- Epoch 11/80 ---
# Batch 0: Loss = 0.1185
# Batch 100: Loss = 0.0536
# Batch 200: Loss = 0.1171
# Batch 300: Loss = 0.0821
# Batch 400: Loss = 0.0310
# Batch 500: Loss = 0.2302
# Batch 600: Loss = 0.1080
# Batch 700: Loss = 0.1805
# Batch 800: Loss = 0.2818
# Batch 900: Loss = 0.0507
# Epoch 11 completed!
#
# --- Epoch 12/80 ---
# Batch 0: Loss = 0.0308
# Batch 100: Loss = 0.1676
# Batch 200: Loss = 0.1214
# Batch 300: Loss = 0.0875
# Batch 400: Loss = 0.1572
# Batch 500: Loss = 0.0693
# Batch 600: Loss = 0.0828
# Batch 700: Loss = 0.1685
# Batch 800: Loss = 0.2077
# Batch 900: Loss = 0.1380
# Epoch 12 completed!
#
# --- Epoch 13/80 ---
# Batch 0: Loss = 0.0482
# Batch 100: Loss = 0.1862
# Batch 200: Loss = 0.1036
# Batch 300: Loss = 0.2619
# Batch 400: Loss = 0.1925
# Batch 500: Loss = 0.1041
# Batch 600: Loss = 0.2741
# Batch 700: Loss = 0.0880
# Batch 800: Loss = 0.0609
# Batch 900: Loss = 0.1123
# Epoch 13 completed!
#
# --- Epoch 14/80 ---
# Batch 0: Loss = 0.1978
# Batch 100: Loss = 0.0935
# Batch 200: Loss = 0.1028
# Batch 300: Loss = 0.1429
# Batch 400: Loss = 0.0859
# Batch 500: Loss = 0.0253
# Batch 600: Loss = 0.0340
# Batch 700: Loss = 0.0569
# Batch 800: Loss = 0.0305
# Batch 900: Loss = 0.2221
# Epoch 14 completed!
#
# --- Epoch 15/80 ---
# Batch 0: Loss = 0.2036
# Batch 100: Loss = 0.0198
# Batch 200: Loss = 0.1351
# Batch 300: Loss = 0.0719
# Batch 400: Loss = 0.0194
# Batch 500: Loss = 0.0557
# Batch 600: Loss = 0.1401
# Batch 700: Loss = 0.0483
# Batch 800: Loss = 0.0822
# Batch 900: Loss = 0.0291
# Epoch 15 completed!
#
# --- Epoch 16/80 ---
# Batch 0: Loss = 0.0516
# Batch 100: Loss = 0.1208
# Batch 200: Loss = 0.0165
# Batch 300: Loss = 0.0723
# Batch 400: Loss = 0.0365
# Batch 500: Loss = 0.1620
# Batch 600: Loss = 0.1181
# Batch 700: Loss = 0.0996
# Batch 800: Loss = 0.1416
# Batch 900: Loss = 0.2951
# Epoch 16 completed!
#
# --- Epoch 17/80 ---
# Batch 0: Loss = 0.1202
# Batch 100: Loss = 0.0558
# Batch 200: Loss = 0.0459
# Batch 300: Loss = 0.1153
# Batch 400: Loss = 0.0377
# Batch 500: Loss = 0.0327
# Batch 600: Loss = 0.0574
# Batch 700: Loss = 0.2347
# Batch 800: Loss = 0.0246
# Batch 900: Loss = 0.1082
# Epoch 17 completed!
#
# --- Epoch 18/80 ---
# Batch 0: Loss = 0.2828
# Batch 100: Loss = 0.1989
# Batch 200: Loss = 0.1886
# Batch 300: Loss = 0.0959
# Batch 400: Loss = 0.0444
# Batch 500: Loss = 0.1409
# Batch 600: Loss = 0.0896
# Batch 700: Loss = 0.1281
# Batch 800: Loss = 0.0292
# Batch 900: Loss = 0.2193
# Epoch 18 completed!
#
# --- Epoch 19/80 ---
# Batch 0: Loss = 0.0495
# Batch 100: Loss = 0.0349
# Batch 200: Loss = 0.1232
# Batch 300: Loss = 0.1603
# Batch 400: Loss = 0.1734
# Batch 500: Loss = 0.1133
# Batch 600: Loss = 0.0222
# Batch 700: Loss = 0.0084
# Batch 800: Loss = 0.0381
# Batch 900: Loss = 0.1752
# Epoch 19 completed!
#
# --- Epoch 20/80 ---
# Batch 0: Loss = 0.0025
# Batch 100: Loss = 0.1302
# Batch 200: Loss = 0.1079
# Batch 300: Loss = 0.0075
# Batch 400: Loss = 0.0364
# Batch 500: Loss = 0.1146
# Batch 600: Loss = 0.0460
# Batch 700: Loss = 0.2889
# Batch 800: Loss = 0.2903
# Batch 900: Loss = 0.0333
# Epoch 20 completed!
#
# --- Epoch 21/80 ---
# Batch 0: Loss = 0.0523
# Batch 100: Loss = 0.1004
# Batch 200: Loss = 0.1721
# Batch 300: Loss = 0.0118
# Batch 400: Loss = 0.0792
# Batch 500: Loss = 0.0423
# Batch 600: Loss = 0.1245
# Batch 700: Loss = 0.3127
# Batch 800: Loss = 0.1504
# Batch 900: Loss = 0.0615
# Epoch 21 completed!
#
# --- Epoch 22/80 ---
# Batch 0: Loss = 0.1174
# Batch 100: Loss = 0.0236
# Batch 200: Loss = 0.0764
# Batch 300: Loss = 0.0021
# Batch 400: Loss = 0.0459
# Batch 500: Loss = 0.0743
# Batch 600: Loss = 0.0639
# Batch 700: Loss = 0.0938
# Batch 800: Loss = 0.0685
# Batch 900: Loss = 0.1516
# Epoch 22 completed!
#
# --- Epoch 23/80 ---
# Batch 0: Loss = 0.0914
# Batch 100: Loss = 0.0444
# Batch 200: Loss = 0.0192
# Batch 300: Loss = 0.1525
# Batch 400: Loss = 0.0963
# Batch 500: Loss = 0.0715
# Batch 600: Loss = 0.0178
# Batch 700: Loss = 0.0805
# Batch 800: Loss = 0.0678
# Batch 900: Loss = 0.1233
# Epoch 23 completed!
#
# --- Epoch 24/80 ---
# Batch 0: Loss = 0.0568
# Batch 100: Loss = 0.0040
# Batch 200: Loss = 0.0463
# Batch 300: Loss = 0.0262
# Batch 400: Loss = 0.0265
# Batch 500: Loss = 0.1446
# Batch 600: Loss = 0.1148
# Batch 700: Loss = 0.0389
# Batch 800: Loss = 0.0332
# Batch 900: Loss = 0.1087
# Epoch 24 completed!
#
# --- Epoch 25/80 ---
# Batch 0: Loss = 0.0444
# Batch 100: Loss = 0.1097
# Batch 200: Loss = 0.2388
# Batch 300: Loss = 0.0737
# Batch 400: Loss = 0.0065
# Batch 500: Loss = 0.1183
# Batch 600: Loss = 0.0282
# Batch 700: Loss = 0.1324
# Batch 800: Loss = 0.0808
# Batch 900: Loss = 0.0563
# Epoch 25 completed!
#
# --- Epoch 26/80 ---
# Batch 0: Loss = 0.0969
# Batch 100: Loss = 0.2708
# Batch 200: Loss = 0.0423
# Batch 300: Loss = 0.0262
# Batch 400: Loss = 0.1064
# Batch 500: Loss = 0.0094
# Batch 600: Loss = 0.1185
# Batch 700: Loss = 0.0645
# Batch 800: Loss = 0.1415
# Batch 900: Loss = 0.0598
# Epoch 26 completed!
#
# --- Epoch 27/80 ---
# Batch 0: Loss = 0.0502
# Batch 100: Loss = 0.0452
# Batch 200: Loss = 0.1581
# Batch 300: Loss = 0.0322
# Batch 400: Loss = 0.1394
# Batch 500: Loss = 0.0180
# Batch 600: Loss = 0.0688
# Batch 700: Loss = 0.0632
# Batch 800: Loss = 0.0537
# Batch 900: Loss = 0.0787
# Epoch 27 completed!
#
# --- Epoch 28/80 ---
# Batch 0: Loss = 0.0048
# Batch 100: Loss = 0.0512
# Batch 200: Loss = 0.2740
# Batch 300: Loss = 0.0749
# Batch 400: Loss = 0.1311
# Batch 500: Loss = 0.0046
# Batch 600: Loss = 0.3669
# Batch 700: Loss = 0.0181
# Batch 800: Loss = 0.1255
# Batch 900: Loss = 0.0633
# Epoch 28 completed!
#
# --- Epoch 29/80 ---
# Batch 0: Loss = 0.0204
# Batch 100: Loss = 0.0242
# Batch 200: Loss = 0.0083
# Batch 300: Loss = 0.0656
# Batch 400: Loss = 0.1309
# Batch 500: Loss = 0.1941
# Batch 600: Loss = 0.0021
# Batch 700: Loss = 0.2765
# Batch 800: Loss = 0.1543
# Batch 900: Loss = 0.0840
# Epoch 29 completed!
#
# --- Epoch 30/80 ---
# Batch 0: Loss = 0.1628
# Batch 100: Loss = 0.0206
# Batch 200: Loss = 0.1432
# Batch 300: Loss = 0.1451
# Batch 400: Loss = 0.0145
# Batch 500: Loss = 0.0058
# Batch 600: Loss = 0.0144
# Batch 700: Loss = 0.0060
# Batch 800: Loss = 0.0596
# Batch 900: Loss = 0.0973
# Epoch 30 completed!
#
# --- Epoch 31/80 ---
# Batch 0: Loss = 0.0792
# Batch 100: Loss = 0.0350
# Batch 200: Loss = 0.0784
# Batch 300: Loss = 0.0504
# Batch 400: Loss = 0.1076
# Batch 500: Loss = 0.0189
# Batch 600: Loss = 0.0960
# Batch 700: Loss = 0.1727
# Batch 800: Loss = 0.0176
# Batch 900: Loss = 0.0623
# Epoch 31 completed!
#
# --- Epoch 32/80 ---
# Batch 0: Loss = 0.0777
# Batch 100: Loss = 0.1460
# Batch 200: Loss = 0.0030
# Batch 300: Loss = 0.0388
# Batch 400: Loss = 0.0290
# Batch 500: Loss = 0.0026
# Batch 600: Loss = 0.0348
# Batch 700: Loss = 0.0389
# Batch 800: Loss = 0.0633
# Batch 900: Loss = 0.0026
# Epoch 32 completed!
#
# --- Epoch 33/80 ---
# Batch 0: Loss = 0.0282
# Batch 100: Loss = 0.0301
# Batch 200: Loss = 0.0450
# Batch 300: Loss = 0.1796
# Batch 400: Loss = 0.0768
# Batch 500: Loss = 0.0656
# Batch 600: Loss = 0.1395
# Batch 700: Loss = 0.0432
# Batch 800: Loss = 0.2084
# Batch 900: Loss = 0.0536
# Epoch 33 completed!
#
# --- Epoch 34/80 ---
# Batch 0: Loss = 0.0058
# Batch 100: Loss = 0.0519
# Batch 200: Loss = 0.0264
# Batch 300: Loss = 0.0482
# Batch 400: Loss = 0.0722
# Batch 500: Loss = 0.0555
# Batch 600: Loss = 0.0341
# Batch 700: Loss = 0.0405
# Batch 800: Loss = 0.2872
# Batch 900: Loss = 0.0213
# Epoch 34 completed!
#
# --- Epoch 35/80 ---
# Batch 0: Loss = 0.0899
# Batch 100: Loss = 0.1775
# Batch 200: Loss = 0.0235
# Batch 300: Loss = 0.0074
# Batch 400: Loss = 0.1670
# Batch 500: Loss = 0.1018
# Batch 600: Loss = 0.0596
# Batch 700: Loss = 0.0018
# Batch 800: Loss = 0.1243
# Batch 900: Loss = 0.0665
# Epoch 35 completed!
#
# --- Epoch 36/80 ---
# Batch 0: Loss = 0.1311
# Batch 100: Loss = 0.0490
# Batch 200: Loss = 0.1393
# Batch 300: Loss = 0.0031
# Batch 400: Loss = 0.1042
# Batch 500: Loss = 0.0930
# Batch 600: Loss = 0.2373
# Batch 700: Loss = 0.1284
# Batch 800: Loss = 0.0691
# Batch 900: Loss = 0.0653
# Epoch 36 completed!
#
# --- Epoch 37/80 ---
# Batch 0: Loss = 0.1748
# Batch 100: Loss = 0.2298
# Batch 200: Loss = 0.1290
# Batch 300: Loss = 0.0290
# Batch 400: Loss = 0.0580
# Batch 500: Loss = 0.1107
# Batch 600: Loss = 0.0683
# Batch 700: Loss = 0.0163
# Batch 800: Loss = 0.1448
# Batch 900: Loss = 0.0726
# Epoch 37 completed!
#
# --- Epoch 38/80 ---
# Batch 0: Loss = 0.0359
# Batch 100: Loss = 0.0292
# Batch 200: Loss = 0.0199
# Batch 300: Loss = 0.0277
# Batch 400: Loss = 0.1140
# Batch 500: Loss = 0.1385
# Batch 600: Loss = 0.0093
# Batch 700: Loss = 0.0147
# Batch 800: Loss = 0.3341
# Batch 900: Loss = 0.0307
# Epoch 38 completed!
#
# --- Epoch 39/80 ---
# Batch 0: Loss = 0.0640
# Batch 100: Loss = 0.0298
# Batch 200: Loss = 0.0277
# Batch 300: Loss = 0.0208
# Batch 400: Loss = 0.0171
# Batch 500: Loss = 0.0054
# Batch 600: Loss = 0.0092
# Batch 700: Loss = 0.0599
# Batch 800: Loss = 0.1718
# Batch 900: Loss = 0.0576
# Epoch 39 completed!
#
# --- Epoch 40/80 ---
# Batch 0: Loss = 0.0779
# Batch 100: Loss = 0.1309
# Batch 200: Loss = 0.1293
# Batch 300: Loss = 0.0310
# Batch 400: Loss = 0.1359
# Batch 500: Loss = 0.0221
# Batch 600: Loss = 0.0486
# Batch 700: Loss = 0.0179
# Batch 800: Loss = 0.1693
# Batch 900: Loss = 0.0504
# Epoch 40 completed!
#
# --- Epoch 41/80 ---
# Batch 0: Loss = 0.0610
# Batch 100: Loss = 0.0316
# Batch 200: Loss = 0.2217
# Batch 300: Loss = 0.0105
# Batch 400: Loss = 0.0438
# Batch 500: Loss = 0.1295
# Batch 600: Loss = 0.0202
# Batch 700: Loss = 0.0533
# Batch 800: Loss = 0.0342
# Batch 900: Loss = 0.0294
# Epoch 41 completed!
#
# --- Epoch 42/80 ---
# Batch 0: Loss = 0.0081
# Batch 100: Loss = 0.0276
# Batch 200: Loss = 0.0177
# Batch 300: Loss = 0.0041
# Batch 400: Loss = 0.1064
# Batch 500: Loss = 0.0894
# Batch 600: Loss = 0.0068
# Batch 700: Loss = 0.0048
# Batch 800: Loss = 0.0299
# Batch 900: Loss = 0.0090
# Epoch 42 completed!
#
# --- Epoch 43/80 ---
# Batch 0: Loss = 0.0508
# Batch 100: Loss = 0.0199
# Batch 200: Loss = 0.0459
# Batch 300: Loss = 0.1738
# Batch 400: Loss = 0.0132
# Batch 500: Loss = 0.0614
# Batch 600: Loss = 0.0011
# Batch 700: Loss = 0.1247
# Batch 800: Loss = 0.0719
# Batch 900: Loss = 0.0942
# Epoch 43 completed!
#
# --- Epoch 44/80 ---
# Batch 0: Loss = 0.0914
# Batch 100: Loss = 0.0917
# Batch 200: Loss = 0.0668
# Batch 300: Loss = 0.0011
# Batch 400: Loss = 0.0137
# Batch 500: Loss = 0.0985
# Batch 600: Loss = 0.0473
# Batch 700: Loss = 0.0415
# Batch 800: Loss = 0.0027
# Batch 900: Loss = 0.0027
# Epoch 44 completed!
#
# --- Epoch 45/80 ---
# Batch 0: Loss = 0.0087
# Batch 100: Loss = 0.0022
# Batch 200: Loss = 0.0235
# Batch 300: Loss = 0.0546
# Batch 400: Loss = 0.0213
# Batch 500: Loss = 0.0364
# Batch 600: Loss = 0.0070
# Batch 700: Loss = 0.2416
# Batch 800: Loss = 0.1461
# Batch 900: Loss = 0.0553
# Epoch 45 completed!
#
# --- Epoch 46/80 ---
# Batch 0: Loss = 0.0016
# Batch 100: Loss = 0.0139
# Batch 200: Loss = 0.0010
# Batch 300: Loss = 0.0619
# Batch 400: Loss = 0.1233
# Batch 500: Loss = 0.0985
# Batch 600: Loss = 0.0330
# Batch 700: Loss = 0.0747
# Batch 800: Loss = 0.0176
# Batch 900: Loss = 0.1348
# Epoch 46 completed!
#
# --- Epoch 47/80 ---
# Batch 0: Loss = 0.1394
# Batch 100: Loss = 0.0467
# Batch 200: Loss = 0.0786
# Batch 300: Loss = 0.0135
# Batch 400: Loss = 0.0216
# Batch 500: Loss = 0.0140
# Batch 600: Loss = 0.1706
# Batch 700: Loss = 0.0953
# Batch 800: Loss = 0.0138
# Batch 900: Loss = 0.1765
# Epoch 47 completed!
#
# --- Epoch 48/80 ---
# Batch 0: Loss = 0.0278
# Batch 100: Loss = 0.0031
# Batch 200: Loss = 0.1206
# Batch 300: Loss = 0.0004
# Batch 400: Loss = 0.0011
# Batch 500: Loss = 0.0521
# Batch 600: Loss = 0.0319
# Batch 700: Loss = 0.0057
# Batch 800: Loss = 0.0134
# Batch 900: Loss = 0.1241
# Epoch 48 completed!
#
# --- Epoch 49/80 ---
# Batch 0: Loss = 0.1174
# Batch 100: Loss = 0.0079
# Batch 200: Loss = 0.0557
# Batch 300: Loss = 0.0817
# Batch 400: Loss = 0.0558
# Batch 500: Loss = 0.1759
# Batch 600: Loss = 0.0235
# Batch 700: Loss = 0.1041
# Batch 800: Loss = 0.2026
# Batch 900: Loss = 0.0331
# Epoch 49 completed!
#
# --- Epoch 50/80 ---
# Batch 0: Loss = 0.0146
# Batch 100: Loss = 0.0018
# Batch 200: Loss = 0.0248
# Batch 300: Loss = 0.0806
# Batch 400: Loss = 0.0666
# Batch 500: Loss = 0.1169
# Batch 600: Loss = 0.1327
# Batch 700: Loss = 0.3216
# Batch 800: Loss = 0.0480
# Batch 900: Loss = 0.0983
# Epoch 50 completed!
#
# --- Epoch 51/80 ---
# Batch 0: Loss = 0.1167
# Batch 100: Loss = 0.0988
# Batch 200: Loss = 0.0030
# Batch 300: Loss = 0.0959
# Batch 400: Loss = 0.0589
# Batch 500: Loss = 0.0013
# Batch 600: Loss = 0.0090
# Batch 700: Loss = 0.0968
# Batch 800: Loss = 0.0259
# Batch 900: Loss = 0.0922
# Epoch 51 completed!
#
# --- Epoch 52/80 ---
# Batch 0: Loss = 0.0148
# Batch 100: Loss = 0.0004
# Batch 200: Loss = 0.1033
# Batch 300: Loss = 0.2830
# Batch 400: Loss = 0.0289
# Batch 500: Loss = 0.0275
# Batch 600: Loss = 0.2004
# Batch 700: Loss = 0.1146
# Batch 800: Loss = 0.1522
# Batch 900: Loss = 0.0671
# Epoch 52 completed!
#
# --- Epoch 53/80 ---
# Batch 0: Loss = 0.1693
# Batch 100: Loss = 0.0206
# Batch 200: Loss = 0.1466
# Batch 300: Loss = 0.0129
# Batch 400: Loss = 0.0284
# Batch 500: Loss = 0.0089
# Batch 600: Loss = 0.0750
# Batch 700: Loss = 0.1258
# Batch 800: Loss = 0.1403
# Batch 900: Loss = 0.0158
# Epoch 53 completed!
#
# --- Epoch 54/80 ---
# Batch 0: Loss = 0.0903
# Batch 100: Loss = 0.0718
# Batch 200: Loss = 0.0211
# Batch 300: Loss = 0.0868
# Batch 400: Loss = 0.0004
# Batch 500: Loss = 0.3254
# Batch 600: Loss = 0.1835
# Batch 700: Loss = 0.0142
# Batch 800: Loss = 0.0530
# Batch 900: Loss = 0.0603
# Epoch 54 completed!
#
# --- Epoch 55/80 ---
# Batch 0: Loss = 0.0361
# Batch 100: Loss = 0.1457
# Batch 200: Loss = 0.0785
# Batch 300: Loss = 0.3928
# Batch 400: Loss = 0.0696
# Batch 500: Loss = 0.0079
# Batch 600: Loss = 0.0019
# Batch 700: Loss = 0.2445
# Batch 800: Loss = 0.1018
# Batch 900: Loss = 0.0028
# Epoch 55 completed!
#
# --- Epoch 56/80 ---
# Batch 0: Loss = 0.0781
# Batch 100: Loss = 0.0533
# Batch 200: Loss = 0.0121
# Batch 300: Loss = 0.0931
# Batch 400: Loss = 0.0250
# Batch 500: Loss = 0.0878
# Batch 600: Loss = 0.0132
# Batch 700: Loss = 0.0390
# Batch 800: Loss = 0.0753
# Batch 900: Loss = 0.0038
# Epoch 56 completed!
#
# --- Epoch 57/80 ---
# Batch 0: Loss = 0.0352
# Batch 100: Loss = 0.0724
# Batch 200: Loss = 0.0910
# Batch 300: Loss = 0.1182
# Batch 400: Loss = 0.0909
# Batch 500: Loss = 0.0190
# Batch 600: Loss = 0.1383
# Batch 700: Loss = 0.2818
# Batch 800: Loss = 0.1247
# Batch 900: Loss = 0.0292
# Epoch 57 completed!
#
# --- Epoch 58/80 ---
# Batch 0: Loss = 0.0516
# Batch 100: Loss = 0.0189
# Batch 200: Loss = 0.0014
# Batch 300: Loss = 0.0489
# Batch 400: Loss = 0.0143
# Batch 500: Loss = 0.0060
# Batch 600: Loss = 0.0278
# Batch 700: Loss = 0.0285
# Batch 800: Loss = 0.0661
# Batch 900: Loss = 0.0562
# Epoch 58 completed!
#
# --- Epoch 59/80 ---
# Batch 0: Loss = 0.0028
# Batch 100: Loss = 0.0114
# Batch 200: Loss = 0.1027
# Batch 300: Loss = 0.0814
# Batch 400: Loss = 0.0814
# Batch 500: Loss = 0.0306
# Batch 600: Loss = 0.1085
# Batch 700: Loss = 0.0617
# Batch 800: Loss = 0.0945
# Batch 900: Loss = 0.0017
# Epoch 59 completed!
#
# --- Epoch 60/80 ---
# Batch 0: Loss = 0.0339
# Batch 100: Loss = 0.0214
# Batch 200: Loss = 0.0170
# Batch 300: Loss = 0.0531
# Batch 400: Loss = 0.0873
# Batch 500: Loss = 0.0169
# Batch 600: Loss = 0.0013
# Batch 700: Loss = 0.1007
# Batch 800: Loss = 0.0597
# Batch 900: Loss = 0.0640
# Epoch 60 completed!
#
# --- Epoch 61/80 ---
# Batch 0: Loss = 0.0201
# Batch 100: Loss = 0.1660
# Batch 200: Loss = 0.0005
# Batch 300: Loss = 0.0162
# Batch 400: Loss = 0.0063
# Batch 500: Loss = 0.0849
# Batch 600: Loss = 0.0963
# Batch 700: Loss = 0.2586
# Batch 800: Loss = 0.0096
# Batch 900: Loss = 0.0423
# Epoch 61 completed!
#
# --- Epoch 62/80 ---
# Batch 0: Loss = 0.0013
# Batch 100: Loss = 0.0018
# Batch 200: Loss = 0.3646
# Batch 300: Loss = 0.0395
# Batch 400: Loss = 0.1119
# Batch 500: Loss = 0.0146
# Batch 600: Loss = 0.0101
# Batch 700: Loss = 0.0428
# Batch 800: Loss = 0.1183
# Batch 900: Loss = 0.2217
# Epoch 62 completed!
#
# --- Epoch 63/80 ---
# Batch 0: Loss = 0.0865
# Batch 100: Loss = 0.1357
# Batch 200: Loss = 0.2225
# Batch 300: Loss = 0.0391
# Batch 400: Loss = 0.0115
# Batch 500: Loss = 0.1562
# Batch 600: Loss = 0.0920
# Batch 700: Loss = 0.2734
# Batch 800: Loss = 0.1192
# Batch 900: Loss = 0.0230
# Epoch 63 completed!
#
# --- Epoch 64/80 ---
# Batch 0: Loss = 0.1508
# Batch 100: Loss = 0.2203
# Batch 200: Loss = 0.1696
# Batch 300: Loss = 0.0279
# Batch 400: Loss = 0.0043
# Batch 500: Loss = 0.0441
# Batch 600: Loss = 0.0223
# Batch 700: Loss = 0.0147
# Batch 800: Loss = 0.0145
# Batch 900: Loss = 0.0363
# Epoch 64 completed!
#
# --- Epoch 65/80 ---
# Batch 0: Loss = 0.1854
# Batch 100: Loss = 0.0265
# Batch 200: Loss = 0.0040
# Batch 300: Loss = 0.1548
# Batch 400: Loss = 0.0022
# Batch 500: Loss = 0.8662
# Batch 600: Loss = 0.0184
# Batch 700: Loss = 0.0016
# Batch 800: Loss = 0.0208
# Batch 900: Loss = 0.0573
# Epoch 65 completed!
#
# --- Epoch 66/80 ---
# Batch 0: Loss = 0.0560
# Batch 100: Loss = 0.0104
# Batch 200: Loss = 0.0055
# Batch 300: Loss = 0.1312
# Batch 400: Loss = 0.0276
# Batch 500: Loss = 0.0461
# Batch 600: Loss = 0.0048
# Batch 700: Loss = 0.0457
# Batch 800: Loss = 0.0916
# Batch 900: Loss = 0.0763
# Epoch 66 completed!
#
# --- Epoch 67/80 ---
# Batch 0: Loss = 0.0321
# Batch 100: Loss = 0.0036
# Batch 200: Loss = 0.0822
# Batch 300: Loss = 0.0730
# Batch 400: Loss = 0.0064
# Batch 500: Loss = 0.0928
# Batch 600: Loss = 0.0829
# Batch 700: Loss = 0.0093
# Batch 800: Loss = 0.0122
# Batch 900: Loss = 0.0043
# Epoch 67 completed!
#
# --- Epoch 68/80 ---
# Batch 0: Loss = 0.0238
# Batch 100: Loss = 0.0003
# Batch 200: Loss = 0.0008
# Batch 300: Loss = 0.0977
# Batch 400: Loss = 0.1527
# Batch 500: Loss = 0.0038
# Batch 600: Loss = 0.0149
# Batch 700: Loss = 0.2269
# Batch 800: Loss = 0.0988
# Batch 900: Loss = 0.0030
# Epoch 68 completed!
#
# --- Epoch 69/80 ---
# Batch 0: Loss = 0.0114
# Batch 100: Loss = 0.1023
# Batch 200: Loss = 0.0014
# Batch 300: Loss = 0.0005
# Batch 400: Loss = 0.0820
# Batch 500: Loss = 0.0169
# Batch 600: Loss = 0.0038
# Batch 700: Loss = 0.0447
# Batch 800: Loss = 0.0204
# Batch 900: Loss = 0.1567
# Epoch 69 completed!
#
# --- Epoch 70/80 ---
# Batch 0: Loss = 0.0254
# Batch 100: Loss = 0.0487
# Batch 200: Loss = 0.1203
# Batch 300: Loss = 0.2237
# Batch 400: Loss = 0.0115
# Batch 500: Loss = 0.0298
# Batch 600: Loss = 0.0017
# Batch 700: Loss = 0.0027
# Batch 800: Loss = 0.2129
# Batch 900: Loss = 0.0626
# Epoch 70 completed!
#
# --- Epoch 71/80 ---
# Batch 0: Loss = 0.1281
# Batch 100: Loss = 0.0607
# Batch 200: Loss = 0.0889
# Batch 300: Loss = 0.0796
# Batch 400: Loss = 0.0036
# Batch 500: Loss = 0.2522
# Batch 600: Loss = 0.0592
# Batch 700: Loss = 0.0024
# Batch 800: Loss = 0.2468
# Batch 900: Loss = 0.0439
# Epoch 71 completed!
#
# --- Epoch 72/80 ---
# Batch 0: Loss = 0.0877
# Batch 100: Loss = 0.0013
# Batch 200: Loss = 0.0379
# Batch 300: Loss = 0.1016
# Batch 400: Loss = 0.0029
# Batch 500: Loss = 0.0013
# Batch 600: Loss = 0.0782
# Batch 700: Loss = 0.1115
# Batch 800: Loss = 0.0613
# Batch 900: Loss = 0.0215
# Epoch 72 completed!
#
# --- Epoch 73/80 ---
# Batch 0: Loss = 0.4592
# Batch 100: Loss = 0.0105
# Batch 200: Loss = 0.0144
# Batch 300: Loss = 0.3220
# Batch 400: Loss = 0.1906
# Batch 500: Loss = 0.0700
# Batch 600: Loss = 0.0153
# Batch 700: Loss = 0.0098
# Batch 800: Loss = 0.0144
# Batch 900: Loss = 0.0042
# Epoch 73 completed!
#
# --- Epoch 74/80 ---
# Batch 0: Loss = 0.1159
# Batch 100: Loss = 0.0414
# Batch 200: Loss = 0.0937
# Batch 300: Loss = 0.0094
# Batch 400: Loss = 0.0349
# Batch 500: Loss = 0.1464
# Batch 600: Loss = 0.1093
# Batch 700: Loss = 0.0047

# %%
def test():
    model.eval() 
    correct = 0
    
    with torch.no_grad(): 
        for data, target in test_loader:
            output = model(data)
            
            prediction = output.argmax(dim=1) 
            
            correct += (prediction == target).sum().item()

    accuracy = correct / len(test_loader.dataset)
    print(f"Test Accuracy: {accuracy:.1%}")

test()
# Out:
# Test Accuracy: 94.6%
